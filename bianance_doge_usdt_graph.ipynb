# %% [markdown]
# <a href="https://colab.research.google.com/github/EdwinKestler/colab-binance-doge-usdt-graph/blob/main/bianance_doge_usdt_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *italicized text*# Install CCXT

# %%
# !pip install ccxt
# Out:
# Collecting ccxt
#   Downloading ccxt-1.54.47-py2.py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 8.4 MB/s
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.7/dist-packages (from ccxt) (2021.5.30)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from ccxt) (2.23.0)
# Requirement already satisfied: setuptools>=38.5.1 in /usr/local/lib/python3.7/dist-packages (from ccxt) (57.2.0)
# Collecting cryptography>=2.6.1
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 44.8 MB/s
# Collecting aiodns<2.1,>=1.1.1
#   Downloading aiodns-2.0.0-py2.py3-none-any.whl (4.8 kB)
# Collecting aiohttp<3.8,>=3.7.4
#   Downloading aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 40.7 MB/s
# Collecting yarl==1.6.3
#   Downloading yarl-1.6.3-cp37-cp37m-manylinux2014_x86_64.whl (294 kB)
#      |████████████████████████████████| 294 kB 48.2 MB/s
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl==1.6.3->ccxt) (2.10)
# Collecting multidict>=4.0
#   Downloading multidict-5.1.0-cp37-cp37m-manylinux2014_x86_64.whl (142 kB)
#      |████████████████████████████████| 142 kB 46.1 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from yarl==1.6.3->ccxt) (3.7.4.3)
# Collecting pycares>=3.0.0
#   Downloading pycares-4.0.0-cp37-cp37m-manylinux2010_x86_64.whl (291 kB)
#      |████████████████████████████████| 291 kB 37.6 MB/s
# Requirement already satisfied: chardet<5.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<3.8,>=3.7.4->ccxt) (3.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<3.8,>=3.7.4->ccxt) (21.2.0)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.6.1->ccxt) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt) (2.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->ccxt) (1.24.3)
# Installing collected packages: multidict, yarl, pycares, async-timeout, cryptography, aiohttp, aiodns, ccxt
# Successfully installed aiodns-2.0.0 aiohttp-3.7.4.post0 async-timeout-3.0.1 ccxt-1.54.47 cryptography-3.4.7 multidict-5.1.0 pycares-4.0.0 yarl-1.6.3

# %% [markdown]
# # Load Binance

# %%
import ccxt

# Load Binance
binance = ccxt.binance ()
binance.load_markets ()

print ('binance: %d markets loaded!' % len (binance.markets))
# Out:
# binance: 1561 markets loaded!

# %% [markdown]
# # Set Up The Chart Drawing

# %%
# Enables 2x resolution for Retina displays
# %config InlineBackend.figure_format = 'retina'

# This is the library we will use for chart drawing
import matplotlib.pyplot as plt

# Configure the look
plt.style.use ('seaborn-white')
plt.rcParams["figure.figsize"] = [15,6]

# %% [markdown]
# # Display ETH/USDT prices

# %%
import pandas as pd
from datetime import datetime

pair = 'DOGE/USDT'

# Load OHLCV (open/high/low/close/volume) data with 1-day resolution
ohlcv = binance.fetch_ohlcv (pair, '1h')

# Get closing prices for each day
prices = [x[4] for x in ohlcv]

# Convert Unix timestamps to Python dates
dates = [datetime.fromtimestamp (x[0] // 1000) for x in ohlcv]

# Prepare a Pandas series object
data = pd.Series (prices, index=dates) 

# Draw a simple line chart
data.plot ()
